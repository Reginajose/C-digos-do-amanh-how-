# %% [markdown]
# <a href="https://colab.research.google.com/github/Reginajose/C-digos-do-amanh-how-/blob/Reginajose-patch-1/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
uploaded = files.upload()
df = pd.read_excel('IDEB_ensino_medio_municipios_2023.xlsx')
df.head()
# Out:
#      <input type="file" id="files-94761d9b-842b-4104-86ae-749ab1f2b18f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-94761d9b-842b-4104-86ae-749ab1f2b18f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd
uploaded = files.upload()
df = pd.read_excel('IDEB_ensino_medio_municipios_2023.xlsx')
df.info( )
# Out:
#      <input type="file" id="files-af4532fa-9701-42fc-8f3d-bd5e24c469ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af4532fa-9701-42fc-8f3d-bd5e24c469ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df
# Out:
#                                              Sigla da UF Código do Município  \
# 0                                                    NaN                 NaN
# 1                                                    NaN                 NaN
# 2                                                  SG_UF        CO_MUNICIPIO
# 3                                                     RO             1100015
# 4                                                     RO             1100015
# ...                                                  ...                 ...
# 11733  que foram definidas (https://download.inep.gov...                 NaN
# 11734                         federado de 2007 até 2021;                 NaN
# 11735  (3) Com o fim do primeiro ciclo do Ideb, o Ine...                 NaN
# 11736  informações ver Portaria nº 26 de 29/01/2024 (...                 NaN
# 11737  Portaria nº 231 de 17/06/2024 (https://www.in....                 NaN
#
# ...

# %%
df['Nome do Município'].isnull()
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 11733     True
# 11734     True
# 11735     True
# 11736     True
# 11737     True
# Name: Nome do Município, Length: 11738, dtype: bool

# %%
df[df['Nome do Município'].isnull()]
# Out:
#                                              Sigla da UF Código do Município  \
# 0                                                    NaN                 NaN
# 1                                                    NaN                 NaN
# 11724                                                NaN                 NaN
# 11725                                    Fonte: MEC/Inep                 NaN
# 11726  Notas: (***): A taxa de aprovação do ensino mé...                 NaN
# 11727  ND - Número de participantes no SAEB insuficie...                 NaN
# 11728  ND*** - Município com pelo menos 20% do materi...                 NaN
# 11729  (1) Ver Nota informativa do Ideb de 2021 (http...                 NaN
# 11730  Relatório de Resultados do Saeb de 2021 (https...                 NaN
# 11731  para maiores informações sobre o impacto da pa...                 NaN
# 11732  (2) O primeiro ciclo do Ideb considera as meta...                 NaN
# ...
