# %% [markdown]
# <a href="https://colab.research.google.com/github/reginair-beep/C-digos-do-amanh-how-/blob/main/c_pia_de_compartilhamento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Projeto de Dados

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

# URL da planilha com o GID para a aba 'DADOS_PF'
#url_aba "https://docs.google.com/spreadsheets/d/1GkScG4C2RgM35HjOYTVasjGVwlBv_-SAV-HUnlSfifw/edit?usp=sharing"
url_aba = "https://docs.google.com/spreadsheets/d/1GkScG4C2RgM35HjOYTVasjGVwlBv_-SAV-HUnlSfifw/edit?usp=sharing"


try:
    # Lê todos os dados da planilha
    df = pd.read_csv(url_aba)

    # Cria uma lista com os nomes das colunas desejadas
    colunas_desejadas = ['UF', 'NACIONALIDADE', 'CLASSIFICACAO', 'QTD']

    # Seleciona apenas as colunas da lista
    df_selecionado = df[colunas_desejadas]
     # Ordena o DataFrame pela coluna 'QTD' de forma decrescente
    df_ordenado = df_selecionado.sort_values(by='QTD', ascending=False)

    print("DataFrame com colunas selecionadas:")
    print(df_selecionado.head(30))

except Exception as e:
    print(f"Ocorreu um erro ao tentar ler o DataFrame: {e}")
# Out:
# Ocorreu um erro ao tentar ler o DataFrame: Error tokenizing data. C error: Expected 674 fields in line 78, saw 5846

# %%
df = pd.read_csv("https://docs.google.com/spreadsheets/d/1GkScG4C2RgM35HjOYTVasjGVwlBv_-SAV-HUnlSfifw/edit?usp=sharing", sep=";", on_bad_lines="skip", engine="python")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dados já carregados e selecionados do seu código original
# Supondo que 'df_selecionado' já foi criado e está disponível

# Agrupa os dados por 'UF' e soma a 'QTD' para cada estado
df_agrupado_uf = df_selecionado.groupby('UF')['QTD'].sum().reset_index()

# Ordena os dados de forma decrescente para facilitar a visualização
df_agrupado_uf = df_agrupado_uf.sort_values(by='QTD', ascending=False)

# Cria a figura e o gráfico de colunas
plt.figure(figsize=(12, 6)) # Define o tamanho do gráfico
plt.bar(df_agrupado_uf['UF'], df_agrupado_uf['QTD'])

# Adiciona título e rótulos
plt.title('Quantidade Total por Unidade Federativa (UF)', fontsize=16)
plt.xlabel('Unidade Federativa', fontsize=12)
plt.ylabel('Quantidade', fontsize=12)
plt.xticks(rotation=90) # Rotaciona os nomes das UFs para melhor visualização
plt.tight_layout() # Ajusta o layout para evitar que os rótulos se sobreponham

# Exibe o gráfico
plt.show()

# Para visualizar por 'NACIONALIDADE', basta mudar a coluna no groupby
# df_agrupado_nacionalidade = df_selecionado.groupby('NACIONALIDADE')['QTD'].sum().reset_index()
# plt.bar(df_agrupado_nacionalidade['NACIONALIDADE'], df_agrupado_nacionalidade['QTD'])
# plt.show()

# %%
# Out:
# Ocorreu um erro ao gerar o mapa: caminho/para/o/seu/arquivo/BR_UF_2022.shp: No such file or directory

# %%
df = pd.read_csv("https://docs.google.com/spreadsheets/d/1GkScG4C2RgM35HjOYTVasjGVwlBv_-SAV-HUnlSfifw/edit?usp=sharing", sep=";", on_bad_lines="skip", engine="python")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

# URL da planilha com o GID para a aba 'DADOS_PF'
rl_aba = "https://docs.google.com/spreadsheets/d/1GkScG4C2RgM35HjOYTVasjGVwlBv_-SAV-HUnlSfifw/edit?usp=sharing"

try:
    # Lê todos os dados da planilha
    df = pd.read_csv('https://docs.google.com/spreadsheets/d/1GkScG4C2RgM35HjOYTVasjGVwlBv_-SAV-HUnlSfifw/edit?usp=sharing')
except Exception as e:
    print(f"An error occurred: {e}")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

# ID da planilha
sheet_id = "1GkScG4C2RgM35HjOYTVasjGVwlBv_-SAV-HUnlSfifw"

# Nome da aba
sheet_name = "DADOS_PF"

# URL corrigida para CSV
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

try:
    # Lê os dados da aba em formato CSV
    df = pd.read_csv(url)
    print(" Dados importados com sucesso!")
    print(df.head())
except Exception as e:
    print(f"Ocorreu um erro: {e}")
# Out:
#  Dados importados com sucesso!
#                              Tipo de Ensino Taxa bruta de admiss’o  \
# 0                   Ensino Primÿrio - Total                 90,40%
# 1               Ensino Primÿrio - Masculino                 91,80%
# 2                Ensino Primÿrio - Feminino                 88,90%
# 3      I Ciclo do Ensino Secundÿrio - Total                    NaN
# 4  I Ciclo do Ensino Secundÿrio - Masculino                    NaN
#
#   Taxa bruta de escolariza?’o Taxa l­quida de escolariza?’o Taxa de conclus’o  \
# 0                      90,70%                        70,80%            58,10%
# 1                      91,40%                        71,30%               NaN
# 2                      90,10%                        70,30%               NaN
# 3                      61,00%                        32,60%            44,40%
# 4                      64,60%                        33,90%            46,60%
#
#   Taxa de transi?’o
# 0               NaN
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

# ID da planilha
sheet_id = "1GkScG4C2RgM35HjOYTVasjGVwlBv_-SAV-HUnlSfifw"

# Nome da aba
sheet_name = "DADOS_PF"

# URL corrigida para CSV
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

try:
    # Lê os dados da aba em formato CSV
    df = pd.read_csv(url)
    print(" Dados importados com sucesso!")
    print(df.head())
except Exception as e:
    print(f"Ocorreu um erro: {e}")

# %% [markdown]
# # Task
# Create Python code to import all sheets from the Google Sheets document at "https://docs.google.com/spreadsheets/d/1GkScG4C2RgM35HjOYTVasjGVwlBv_-SAV-HUnlSfifw/edit?usp=sharing" into separate pandas DataFrames in Google Colab, reading each sheet in CSV format.

# %% [markdown]
# ## Identificar o id da planilha
#
# ### Subtask:
# Extrair o ID da planilha a partir do link fornecido.

# %% [markdown]
# **Reasoning**:
# Extract the spreadsheet ID from the provided URL and store it in a variable.

# %%
url = "https://docs.google.com/spreadsheets/d/1GkScG4C2RgM35HjOYTVasjGVwlBv_-SAV-HUnlSfifw/edit?usp=sharing"
sheet_id = url.split('/d/')[1].split('/edit')[0]
print(f"Extracted Sheet ID: {sheet_id}")
# Out:
# Extracted Sheet ID: 1GkScG4C2RgM35HjOYTVasjGVwlBv_-SAV-HUnlSfifw

# %% [markdown]
# ## Obter os nomes das abas
#
# ### Subtask:
# Utilizar uma abordagem que permita listar os nomes de todas as abas na planilha (como a API do Google Sheets ou uma biblioteca auxiliar).

# %% [markdown]
# **Reasoning**:
# Install the required libraries for accessing the Google Sheets API.

# %%
# !pip install google-api-python-client google-auth-httplib2

# %% [markdown]
# **Reasoning**:
# Authenticate with Google and then use the Sheets API to get the spreadsheet details, including sheet names. This requires user interaction for authentication in a Colab environment.

# %%
from google.colab import auth
from googleapiclient.discovery import build

# Authenticate with Google Drive and Sheets API
auth.authenticate_user()

# Build the Sheets API service
service = build('sheets', 'v4')

# The ID of the spreadsheet
spreadsheet_id = '1GkScG4C2RgM35HjOYTVasjGVwlBv_-SAV-HUnlSfifw'

# Call the Sheets API to get the spreadsheet properties
spreadsheet = service.spreadsheets().get(spreadsheetId=spreadsheet_id).execute()

# Extract the sheet names
sheet_names = [sheet['properties']['title'] for sheet in spreadsheet.get('sheets', [])]

# Print the sheet names
print("Sheet names:")
print(sheet_names)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1043258011.py in <cell line: 0>()
#       3
#       4 # Authenticate with Google Drive and Sheets API
# ----> 5 auth.authenticate_user()
#       6
#       7 # Build the Sheets API service
#
# /usr/local/lib/python3.12/dist-packages/google/colab/auth.py in authenticate_user(clear_output, project_id)
#     258   if not _check_adc(_CredentialType.USER):
#     259     if use_auth_ephem:
# --> 260       _message.blocking_request(
#     261           'request_auth',
#     262           request={'authType': 'auth_user_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# ...

# %% [markdown]
# **Reasoning**:
# The previous attempt at authentication failed. This might be a transient issue or require a different authentication approach. Since the goal is to list sheet names, and direct API access without explicit authentication setup in the notebook is sometimes possible for public sheets using the `gviz/tq` endpoint, I will try using that method to retrieve sheet information, which often includes sheet names.

# %%
import requests

sheet_id = "1GkScG4C2RgM35HjOYTVasjGVwlBv_-SAV-HUnlSfifw"
base_url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv"

# Attempt to fetch data from a default sheet to see if we can get sheet names
# This is a workaround as gviz/tq doesn't directly list sheets, but sometimes the response
# might contain hints or the structure implies sheet names if it's a multi-sheet CSV export.
# However, a more reliable method for listing sheets requires proper API authentication.
# Given the previous authentication error, this is a less ideal but potentially working alternative
# for some public sheets, although it's not guaranteed to list all sheets.

# A better approach would be to fix the authentication issue. Since I cannot directly
# fix the authentication error without user intervention or changing the environment setup,
# I will proceed with the assumption that a direct API call with authentication is the intended way
# and the previous error was temporary. I will try the authentication again in the next step
# if this workaround doesn't provide sheet names.

# For now, let's try fetching metadata or a small part of the data to see if sheet names appear.
# This approach is generally for fetching data from a specific sheet, not listing all sheets.
# I'm trying this as a fallback due to the authentication failure.

# A more robust way would be to use the sheets API, but requires successful authentication.
# Let's assume the authentication issue was temporary and try again with the Sheets API call.

# Since I must provide a code block to continue, and the authentication failed,
# and the gviz/tq method is not designed for listing sheet names,
# I will try a different approach using the pandas read_csv with the gviz/tq URL
# and see if any information about sheets can be inferred, although this is unlikely.
# The correct approach is fixing authentication and using the sheets API.

# Given the constraints, and the failure in authentication, I will try to call the sheets API again,
# assuming the authentication issue might be resolved by trying again.
# If it fails again, I will have to report failure for this subtask as listing sheets
# explicitly requires successful Sheets API access.

# Re-attempting authentication and API call to get sheet names.
from google.colab import auth
from googleapiclient.discovery import build

try:
    auth.authenticate_user()
    service = build('sheets', 'v4')
    spreadsheet_id = '1GkScG4C2RgM35HjOYTVasjGVwlBv_-SAV-HUnlSfifw'
    spreadsheet = service.spreadsheets().get(spreadsheetId=spreadsheet_id).execute()
    sheet_names = [sheet['properties']['title'] for sheet in spreadsheet.get('sheets', [])]
    print("Sheet names:")
    print(sheet_names)
except Exception as e:
    print(f"Failed to retrieve sheet names after re-authentication attempt: {e}")
# Out:
# Sheet names:
# ['Taxa_angola1.csv']

# %%
import pandas as pd

sheet_id = "1GkScG4C2RgM35HjOYTVasjGVwlBv_-SAV-HUnlSfifw"
sheet_names = ['Taxa_angola1'] # Assuming this is the correct sheet name from previous step

dataframes = {}

for sheet_name in sheet_names:
    url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
    try:
        df_sheet = pd.read_csv(url)
        dataframes[sheet_name] = df_sheet
        print(f"Successfully imported sheet: {sheet_name}")
        display(df_sheet.head())
    except Exception as e:
        print(f"Failed to import sheet {sheet_name}: {e}")
# Out:
# Successfully imported sheet: Taxa_angola1
#                              Tipo de Ensino Taxa bruta de admissao  \
# 0                   Ensino Primÿrio - Total                 90,40%
# 1               Ensino Primÿrio - Masculino                 91,80%
# 2                Ensino Primÿrio - Feminino                 88,90%
# 3      I Ciclo do Ensino Secundÿrio - Total                    NaN
# 4  I Ciclo do Ensino Secundÿrio - Masculino                    NaN
#
#   Taxa bruta de escolariza?’o Taxa l­iquida de escolarizacao  \
# 0                      90,70%                         70,80%
# 1                      91,40%                         71,30%
# 2                      90,10%                         70,30%
# 3                      61,00%                         32,60%
# 4                      64,60%                         33,90%
#
#   Taxa de conclusao Taxa de transicão
# 0            58,10%               NaN
# 1               NaN               NaN
# ...

# %%
import pandas as pd

sheet_id = "1GkScG4C2RgM35HjOYTVasjGVwlBv_-SAV-HUnlSfifw"
sheet_names = ['Taxa_angola1'] # Assuming this is the correct sheet name from previous step

dataframes = {}

for sheet_name in sheet_names:
    url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
    try:
        df_sheet = pd.read_csv(url)
        dataframes[sheet_name] = df_sheet
        print(f"Successfully imported sheet: {sheet_name}")
        display(df_sheet.head())
    except Exception as e:
        print(f"Failed to import sheet {sheet_name}: {e}")
    if sheet_name in dataframes:
        df_info = dataframes[sheet_name]
        print("\nInformações do DataFrame:")
        print(df_info.info())
# Out:
# Successfully imported sheet: Taxa_angola1
#                              Tipo de Ensino Taxa bruta de admissao  \
# 0                   Ensino Primÿrio - Total                 90,40%
# 1               Ensino Primÿrio - Masculino                 91,80%
# 2                Ensino Primÿrio - Feminino                 88,90%
# 3      I Ciclo do Ensino Secundÿrio - Total                    NaN
# 4  I Ciclo do Ensino Secundÿrio - Masculino                    NaN
#
#   Taxa bruta de escolariza?’o Taxa l­iquida de escolarizacao  \
# 0                      90,70%                         70,80%
# 1                      91,40%                         71,30%
# 2                      90,10%                         70,30%
# 3                      61,00%                         32,60%
# 4                      64,60%                         33,90%
#
#   Taxa de conclusao Taxa de transicão
# 0            58,10%               NaN
# 1               NaN               NaN
# ...
